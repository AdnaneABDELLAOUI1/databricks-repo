# %%
# Notebook: 00_parametres
CATALOG = "afriquia_lakehouse"
PATH_BRUT = f"/Volumes/{CATALOG}/bronze/fichiers_bruts/"

# Schémas
DB_BRONZE = f"{CATALOG}.bronze"
DB_SILVER = f"{CATALOG}.silver"
DB_GOLD   = f"{CATALOG}.gold"

# Coordonnées Maroc
GPS_BOUNDS = {"lat_min": 21.0, "lat_max": 36.0, "lon_min": -17.0, "lon_max": -1.0}

# Poids du Scoring
WEIGHTS = {"trafic": 0.30, "pop": 0.25, "pauvrete": 0.20, "stations": 0.15, "croissance": 0.10}
